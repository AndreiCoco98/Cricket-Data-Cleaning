# %%
#Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import data

# %%
df = pd.read_excel(r"C:\Users\coco MANEL\Documents\Pandas\CricketData.xlsx")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
#Rename multiple columns

# %%
df = df.rename(columns = {'Mat': 'Matches', 'NO':'Not_Outs', 'HS': 'Highest_Inns_Score', 'BF': 'Balls_Faced', 'SR': 'Batting_Strike_Rate'})

# %%
df
# Out:
#                Player       Span Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1      HC Brook (ENG)  2022-2023      12    20         1  1181
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     GA Headley (WI)  1930-1954      22    40         4  2190
# 4     RG Pollock (SA)  1963-1970      23    41         4  2256
# ..                ...        ...     ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981      74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
df.head(10)
# Out:
#                 Player       Span Matches  Inns  Not_Outs  Runs  \
# 0     DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1       HC Brook (ENG)  2022-2023      12    20         1  1181
# 2       AC Voges (AUS)  2015-2016      20    31         7  1485
# 3      GA Headley (WI)  1930-1954      22    40         4  2190
# 4      RG Pollock (SA)  1963-1970      23    41         4  2256
# 5      GA Headley (WI)  1930-1954      22    40         4  2190
# 6    H Sutcliffe (ENG)  1924-1935      54    84         9  4555
# 7      E Paynter (ENG)  1931-1939      20    31         5  1540
# 8  KF Barrington (ENG)  1955-1968      82   131        15  6806
# 9       ED Weekes (WI)  1948-1958      48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  \
# 0                334  99.94       9800+                58.60   29  13  7  626
# 1                186  62.15        1287                91.76    4   7  1  141
# ...

# %%
#Check null

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()]
# Out:
#                   Player       Span Matches  Inns  Not_Outs  Runs  \
# 9         ED Weekes (WI)  1948-1958      48    81         5  4455
# 16       CL Walcott (WI)  1948-1960      44    74         7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905      20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                 207  58.61         NaN                  NaN   15  19  6
# 16                220  56.68         NaN                  NaN   15  14  1
# 58               144*  48.79         NaN                  NaN    5   6  3
#
#      4s  6s
# 9   258   2
# 16  107  11
# 58   51   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df
# Out:
#                Player       Span Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1      HC Brook (ENG)  2022-2023      12    20         1  1181
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     GA Headley (WI)  1930-1954      22    40         4  2190
# 4     RG Pollock (SA)  1963-1970      23    41         4  2256
# ..                ...        ...     ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981      74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
df[df['Player']== 'ED Weekes (WI)']
# Out:
#            Player       Span Matches  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 9  ED Weekes (WI)  1948-1958      48    81         5  4455                207
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s
# 9  58.61           0                  0.0   15  19  6  258   2

# %%
df[df['Player']== 'CL Walcott (WI)']
# Out:
#              Player       Span Matches  Inns  Not_Outs  Runs  \
# 16  CL Walcott (WI)  1948-1960      44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 16                220  56.68           0                  0.0   15  14  1
#
#      4s  6s
# 16  107  11

# %%
#Drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated()== 1]
# Out:
#                 Player       Span Matches  Inns  Not_Outs   Runs  \
# 5      GA Headley (WI)  1930-1954      22    40         4   2190
# 14  KC Sangakkara (SL)  2000-2015     134   233        17  12400
# 19  JH Kallis (ICC/SA)  1995-2013     166   280        40  13289
# 34    RT Ponting (AUS)  1995-2012     168   287        29  13378
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 5                270*  60.83        416+                56.00   10   5   2
# 14                319  57.40       22882                54.19   38  52  11
# 19                224  55.37       28903                45.97   45  58  16
# 34                257  51.85       22782                58.72   41  62  17
#
#       4s  6s
# 5    104   1
# 14  1491  51
# 19  1488  97
# 34  1509  73

# %%
df[df['Player'].isin(['GA Headley (WI)', 'KC Sangakkara (SL)', 'JH Kallis (ICC/SA)', 'RT Ponting (AUS)'])]
# Out:
#                 Player       Span Matches  Inns  Not_Outs   Runs  \
# 3      GA Headley (WI)  1930-1954      22    40         4   2190
# 5      GA Headley (WI)  1930-1954      22    40         4   2190
# 13  KC Sangakkara (SL)  2000-2015     134   233        17  12400
# 14  KC Sangakkara (SL)  2000-2015     134   233        17  12400
# 18  JH Kallis (ICC/SA)  1995-2013     166   280        40  13289
# 19  JH Kallis (ICC/SA)  1995-2013     166   280        40  13289
# 33    RT Ponting (AUS)  1995-2012     168   287        29  13378
# 34    RT Ponting (AUS)  1995-2012     168   287        29  13378
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3                270*  60.83        416+                56.00   10   5   2
# 5                270*  60.83        416+                56.00   10   5   2
# 13                319  57.40       22882                54.19   38  52  11
# 14                319  57.40       22882                54.19   38  52  11
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GA Headley (WI)', 'KC Sangakkara (SL)', 'JH Kallis (ICC/SA)', 'RT Ponting (AUS)'])]
# Out:
#                 Player       Span Matches  Inns  Not_Outs   Runs  \
# 3      GA Headley (WI)  1930-1954      22    40         4   2190
# 13  KC Sangakkara (SL)  2000-2015     134   233        17  12400
# 18  JH Kallis (ICC/SA)  1995-2013     166   280        40  13289
# 33    RT Ponting (AUS)  1995-2012     168   287        29  13378
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3                270*  60.83        416+                56.00   10   5   2
# 13                319  57.40       22882                54.19   38  52  11
# 18                224  55.37       28903                45.97   45  58  16
# 33                257  51.85       22782                58.72   41  62  17
#
#       4s  6s
# 3    104   1
# 13  1491  51
# 18  1488  97
# 33  1509  73

# %%
#Split up Span into Start and End Date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1930, 1954]
# 4     [1963, 1970]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]
# Out:
# C:\Users\coco MANEL\AppData\Local\Temp\ipykernel_8476\3648638022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]
# Out:
# C:\Users\coco MANEL\AppData\Local\Temp\ipykernel_8476\3090471237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 1      HC Brook (ENG)  2022-2023      12    20         1  1181
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     GA Headley (WI)  1930-1954      22    40         4  2190
# 4     RG Pollock (SA)  1963-1970      23    41         4  2256
# ..                ...        ...     ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981      74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
#Drop Span column

# %%
df = df.drop(['Span'], axis = 1 )

# %%
df.head()
# Out:
#              Player Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)      52    80        10  6996                334  99.94
# 1    HC Brook (ENG)      12    20         1  1181                186  62.15
# 2    AC Voges (AUS)      20    31         7  1485               269*  61.87
# 3   GA Headley (WI)      22    40         4  2190               270*  60.83
# 4   RG Pollock (SA)      23    41         4  2256                274  60.97
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year
# 0       9800+                58.60   29  13  7  626   6        1928       1948
# 1        1287                91.76    4   7  1  141  23        2022       2023
# 2        2667                55.68    5   4  2  186   5        2015       2016
# 3        416+                56.00   10   5  2  104   1        1930       1954
# 4       1707+                54.48    7  11  1  246  11        1963       1970

# %%
#Split up the Country from the player

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [GA Headley , WI)]
# 4       [RG Pollock , SA)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'].str.split( pat = ')')
# Out:
# 0        [AUS, ]
# 1        [ENG, ]
# 2        [AUS, ]
# 3         [WI, ]
# 4         [SA, ]
#          ...
# 61       [AUS, ]
# 62    [ICC/SA, ]
# 63       [AUS, ]
# 64       [AUS, ]
# 65       [ENG, ]
# Name: Country, Length: 62, dtype: object

# %%
df['Country'] = df['Country'].str.split( pat = ')').str[0]
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         WI
# 4         SA
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Country, Length: 62, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]
df['Player']
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 3      GA Headley
# 4      RG Pollock
#           ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 64      SJ McCabe
# 65     DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
df.head()
# Out:
#         Player Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman       52    80        10  6996                334  99.94
# 1    HC Brook       12    20         1  1181                186  62.15
# 2    AC Voges       20    31         7  1485               269*  61.87
# 3  GA Headley       22    40         4  2190               270*  60.83
# 4  RG Pollock       23    41         4  2256                274  60.97
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626   6        1928
# 1        1287                91.76    4   7  1  141  23        2022
# 2        2667                55.68    5   4  2  186   5        2015
# 3        416+                56.00   10   5  2  104   1        1930
# 4       1707+                54.48    7  11  1  246  11        1963
#
#   Final_Year Country
# 0       1948     AUS
# 1       2023     ENG
# 2       2016     AUS
# 3       1954      WI
# ...

# %%
#Change data types

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     270
# 4     274
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype(int)

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df
# Out:
#           Player Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80        10  6996                 334  99.94
# 1      HC Brook       12    20         1  1181                 186  62.15
# 2      AC Voges       20    31         7  1485                 269  61.87
# 3    GA Headley       22    40         4  2190                 270  60.83
# 4    RG Pollock       23    41         4  2256                 274  60.97
# ..           ...     ...   ...       ...   ...                 ...    ...
# 61   KD Walters       74   125        14  5357                 250  48.26
# 62     GC Smith      117   205        13  9265                 277  48.25
# 63  WH Ponsford       29    48         4  2122                 266  48.22
# 64    SJ McCabe       39    62         5  2748                 232  48.21
# 65   DR Jardine       22    33         6  1296                 127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df['Rookie_Year'] = df['Rookie_Year'].astype(int)

# %%
df['Final_Year'] = df['Final_Year'].astype(int)

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Matches'] = df['Matches'].str.split(pat = '*').str[0]

# %%
df['Matches'] = df['Matches'].astype(int)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].astype(float)

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype(int)

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
# Build out Career_Length Column

# %%
df['Career_Length'] = df['Final_Year'] -  df['Rookie_Year']

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1      HC Brook        12    20         1  1181                 186  62.15
# 2      AC Voges        20    31         7  1485                 269  61.87
# 3    GA Headley        22    40         4  2190                 270  60.83
# 4    RG Pollock        23    41         4  2256                 274  60.97
# ..           ...      ...   ...       ...   ...                 ...    ...
# 61   KD Walters        74   125        14  5357                 250  48.26
# 62     GC Smith       117   205        13  9265                 277  48.25
# 63  WH Ponsford        29    48         4  2122                 266  48.22
# 64    SJ McCabe        39    62         5  2748                 232  48.21
# 65   DR Jardine        22    33         6  1296                 127  48.00
#
# ...

# %%
# Crickets in this df what is the average Career length

# %%
df['Career_Length'].mean()
# Out:
# 13.193548387096774

# %%
# Avg Batting for cricketers who played over 10 years

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 47.95727272727274

# %%
# Find number of cricketers who player before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 23

# %%
# max Highest Inns by Country

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('HighInnCountry').reset_index().sort_values('HighInnCountry', ascending = False)
# Out:
#     Country  HighInnCountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 6       IND             254
# 7        NZ             251
# 12      ZIM             232

# %%
# Hundres, Fifties, ducks by Countries

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.312500   8.500000
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.000000  21.000000   5.500000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
